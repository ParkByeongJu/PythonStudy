# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
row_data = pd.read_csv('data/titanic.csv', sep='\t')
row_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
row_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
row_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Name         156 non-null    object
#  4   Sex          156 non-null    object
#  5   Age          126 non-null    float64
#  6   SibSp        156 non-null    int64
#  7   Parch        156 non-null    int64
#  8   Ticket       156 non-null    object
#  9   Fare         156 non-null    float64
#  10  Cabin        31 non-null     object
#  11  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 14.8+ KB

# %%
row_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
plt.plot(row_data['Age'])

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(12, 6))

ax[0].set_title('Survived')
row_data['Survived'].value_counts().plot.pie(autopct='%.1f%%', ax=ax[0])
ax[0].set_ylabel('')
row_data['Survived'].value_counts().plot.bar(ax=ax[1])
plt.rc('font', family='gulim')
ax[1].set_ylabel('명')
ax[1].set_title('Servived')
sns.countplot(x='Survived', data=row_data, ax=ax[2])
ax[2].set_title('Servived')
# Out:
# Text(0.5, 1.0, 'Servived')
# C:\Users\User\.conda\envs\TensorflowPy310\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\User\.conda\envs\TensorflowPy310\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
row_data['Survived'].value_counts().plot.pie(autopct='%.1f%%', explode=[0.1,0])
# Out:
# <Axes: ylabel='count'>

# %%
row_data['Survived'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x='Survived', data=row_data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Pclass', data=row_data)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
row_data['Age'].hist(bins=7)
# Out:
# <Axes: >

# %%
row_data.groupby('Pclass').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\.conda\envs\TensorflowPy310\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\.conda\envs\TensorflowPy310\lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
row_data['age_cut'] = pd.cut(row_data['Age'], bins=[0,3,7,15,30,60,100],
                            include_lowest=True, labels=['baby', 'children', 'teenage', 'young', 'adult', 'old'])

# %%
row_data['age_cut'].head(60)
# Out:
# 0        young
# 1        adult
# 2        young
# 3        adult
# 4        adult
# 5          NaN
# 6        adult
# 7         baby
# 8        young
# 9      teenage
# 10    children
# 11       adult
# 12       young
# 13       adult
# 14     teenage
# 15       adult
# 16        baby
# 17         NaN
# 18       adult
# 19         NaN
# 20       adult
# 21       adult
# 22     teenage
# 23       young
# 24     teenage
# 25       adult
# 26         NaN
# 27       young
# 28         NaN
# 29         NaN
# 30       adult
# 31         NaN
# 32         NaN
# 33         old
# 34       young
# 35       adult
# 36         NaN
# 37       young
# 38       young
# 39     teenage
# 40       adult
# 41       young
# 42         NaN
# 43        baby
# 44       young
# 45         NaN
# 46         NaN
# 47         NaN
# 48         NaN
# 49       young
# 50    children
# 51       young
# 52       adult
# 53       young
# 54         old
# 55         NaN
# 56       young
# 57       young
# ...

# %%
row_data.groupby('age_cut').mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\.conda\envs\TensorflowPy310\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\.conda\envs\TensorflowPy310\lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
plt.subplot(121)
sns.barplot(x='age_cut', y='Survived', data = row_data, ci=False)
plt.subplot(122)
sns.barplot(x='Sex', y='Survived', data=row_data, ci=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6308\3576369891.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='age_cut', y='Survived', data = row_data, ci=False)
# C:\Users\User\AppData\Local\Temp\ipykernel_6308\3576369891.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=row_data, ci=False)
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.countplot(x='Sex', data=row_data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>
